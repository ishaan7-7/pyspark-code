# %%
#%pip install pyarrow

# %% [markdown]
# ## Writer

# %%
# %% [markdown]
# Notebook A — Writer (Producer): writes 1 parquet file per second to ./landing/

# %%
import time
from datetime import datetime, timedelta
from pathlib import Path
from typing import Dict, Tuple, Iterator, Optional, List

import numpy as np
import pandas as pd

FEATURES: List[str] = [f"signal_{i}" for i in range(1, 61)]
TIMESTAMP_COL = "Timestamp"

LANDING_DIR = Path(r"C:\Users\Ishaan Tiwari\Desktop\Kafka\landing")
LANDING_DIR.mkdir(parents=True, exist_ok=True)

# %%
# %%
def format_ts(dt: datetime) -> str:
    """Return 'MM:DD:YYYY hh:mm:ss:ffffff' (6-digit subsecond)."""
    return dt.strftime("%m:%d:%Y %H:%M:%S") + f":{dt.microsecond:06d}"

def make_default_ranges() -> Dict[str, Tuple[float, float]]:
    bands = [(-1.0, 1.0), (-3.0, 3.0), (0.0, 5.0), (-10.0, -2.0), (5.0, 15.0)]
    ranges = {}
    for i, sig in enumerate(FEATURES, start=1):
        lo, hi = bands[(i - 1) % len(bands)]
        ranges[sig] = (lo, hi)
    return ranges

class RowStream:
    """
    Emits 1000 rows per real second. Each row's Timestamp is a string and
    consecutive rows are +1 second apart in simulated time.
    rows_per_sec=200, seed=999
    """
    def __init__(self, rows_per_sec: int = 1000, start_dt: Optional[datetime] = None,
                 per_signal_ranges: Optional[Dict[str, Tuple[float, float]]] = None, seed: int = 42):
        assert rows_per_sec > 0
        self.rows_per_sec = int(rows_per_sec)
        self.rng = np.random.default_rng(seed)
        self.features = FEATURES
        self.per_signal_ranges = per_signal_ranges or make_default_ranges()
        missing = [f for f in self.features if f not in self.per_signal_ranges]
        if missing:
            raise ValueError(f"Missing ranges for: {missing[:5]}{'...' if len(missing)>5 else ''}")
        lows, highs = [], []
        for f in self.features:
            lo, hi = self.per_signal_ranges[f]
            if not (isinstance(lo, (int, float)) and isinstance(hi, (int, float)) and lo < hi):
                raise ValueError(f"Invalid range for {f}: ({lo}, {hi})")
            lows.append(lo); highs.append(hi)
        self.low = np.array(lows, dtype=np.float64)
        self.high = np.array(highs, dtype=np.float64)
        self.width = self.high - self.low
        self.sim_time = (start_dt or datetime.utcnow()).replace(microsecond=0)

    def _gen_batch(self) -> pd.DataFrame:
        n = self.rows_per_sec
        stamps = [format_ts(self.sim_time + timedelta(seconds=i)) for i in range(n)]
        u = self.rng.random(size=(n, len(self.features)), dtype=np.float64)
        vals = (self.low + u * self.width).astype(np.float32, copy=False)
        df = pd.DataFrame(vals, columns=self.features)
        df.insert(0, TIMESTAMP_COL, stamps)
        self.sim_time += timedelta(seconds=n)
        return df

    def stream(self, seconds: Optional[int] = None, real_time: bool = True) -> Iterator[pd.DataFrame]:
        i = 0
        while seconds is None or i < seconds:
            start_wall = time.time()
            yield self._gen_batch()
            i += 1
            if real_time:
                elapsed = time.time() - start_wall
                to_sleep = 1.0 - elapsed
                if to_sleep > 0:
                    time.sleep(to_sleep)

def write_batch_parquet(pdf: pd.DataFrame, base_dir: Path = LANDING_DIR):
    """landing/YYYY=YYYY/MM=MM/DD=DD/HH=hh/mm=mm/ss=ss/part-00000.parquet"""
    first_ts = pdf[TIMESTAMP_COL].iloc[0]  # "MM:DD:YYYY hh:mm:ss:ffffff"
    MM, DD, YYYY_time = first_ts.split(":")[0], first_ts.split(":")[1], first_ts.split(":")[2]
    YYYY = YYYY_time.split()[0]
    hh = first_ts.split()[1].split(":")[0]
    mm = first_ts.split()[1].split(":")[1]
    ss = first_ts.split()[1].split(":")[2]
    out_dir = base_dir / f"YYYY={YYYY}/MM={MM}/DD={DD}/HH={hh}/mm={mm}/ss={ss}"
    out_dir.mkdir(parents=True, exist_ok=True)
    pdf.to_parquet(out_dir / "part-00000.parquet", index=False)

# %% [markdown]
# ### Start Writing and Interrupt Writing

# %%
# %%
stream = RowStream(rows_per_sec=200, seed=999)
try:
    for batch_pdf in stream.stream(seconds=None, real_time=True):
        write_batch_parquet(batch_pdf)
except KeyboardInterrupt:
    print("Stopped real-time producer.")
# Out:
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=22\mm=45\ss=01\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:20:2025 22:45:01:000000  0.557650 -1.966508  3.567864 -3.997319
# 1  08:20:2025 22:45:02:000000  0.435615 -1.497452  4.305065 -2.693646
# 2  08:20:2025 22:45:03:000000  0.270561  2.550678  0.309831 -7.853706
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0   6.711091  0.803849 -2.149311  3.056144 -2.712455  ...  -0.603399
# 1   5.403578 -0.870554 -0.508553  4.713863 -6.981105  ...   0.247433
# 2  12.164513 -0.062574 -2.929401  1.479812 -6.175411  ...  -0.141809
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0   1.312248   3.160212  -3.110476   9.106469  -0.023211   0.653595
# 1   1.355940   3.273074  -5.358946  11.318894  -0.766794  -0.283098
# 2  -2.143357   3.452470  -8.713104   9.513635   0.338778   1.722366
#
#    signal_58  signal_59  signal_60
# 0   4.455869  -3.196947   6.765759
# 1   4.657051  -7.395332   9.115026
# 2   3.375449  -3.383430  12.619571
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=22\mm=48\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=22\mm=51\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=22\mm=55\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=22\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:20:2025 23:18:21:000000 -0.594903 -0.708550  0.176151 -5.012781
# 1  08:20:2025 23:18:22:000000  0.180654  0.920907  2.917449 -2.850291
# 2  08:20:2025 23:18:23:000000 -0.577521 -0.006235  0.845035 -8.919787
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0  11.784066 -0.792336  0.306614  2.533688 -7.787778  ...  -0.401380
# 1  10.125443  0.482303 -0.721890  2.254636 -3.550395  ...   0.610186
# 2   6.928950 -0.257567  2.223237  3.876084 -6.839797  ...  -0.400312
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0  -0.814150   0.748233  -5.388403  12.514279   0.140419  -0.949244
# 1   1.614516   3.404831  -9.936011  14.914085  -0.102191   2.318797
# 2  -2.044011   0.556982  -9.219421  11.938830   0.112997  -2.704527
#
#    signal_58  signal_59  signal_60
# 0   2.222013  -7.493445   7.813152
# 1   2.908922  -9.379972   5.465579
# 2   4.135326  -9.720166   5.081737
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=21\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=25\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=28\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=31\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=35\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=38\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=41\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=45\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=48\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=51\ss=41\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:20:2025 23:51:41:000000 -0.904240 -1.831988  2.204190 -9.575408
# 1  08:20:2025 23:51:42:000000  0.323072 -0.559946  1.328422 -9.642967
# 2  08:20:2025 23:51:43:000000  0.281170  0.562723  0.216382 -7.934168
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0  14.649872  0.772451 -0.841114  4.445071 -2.235332  ...   0.607374
# 1  12.638914  0.192163  1.410345  4.682069 -3.043702  ...   0.862668
# 2  11.392307 -0.368081 -1.567046  0.776475 -5.019119  ...  -0.805608
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0  -1.036450   1.699410  -6.286482   6.291638  -0.068793  -2.177584
# 1   0.582996   1.239173  -4.615798  10.715403  -0.817914  -1.336466
# 2  -2.153333   0.163360  -4.871081   7.419287   0.794751  -2.395710
#
#    signal_58  signal_59  signal_60
# 0   0.996468  -3.614246   6.272677
# 1   3.757965  -3.524204   7.839718
# 2   2.571329  -7.512594  13.619384
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=55\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=20\HH=23\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=21\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=25\ss=01\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 00:25:01:000000 -0.606259  1.195885  1.098789 -5.736253
# 1  08:21:2025 00:25:02:000000  0.036675 -0.411075  0.524030 -3.489799
# 2  08:21:2025 00:25:03:000000 -0.260323 -1.478560  3.137622 -7.713269
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0  14.848886 -0.439795  1.464839  2.696017 -8.703892  ...   0.236848
# 1  11.791642 -0.134804  2.268577  0.463288 -2.394898  ...  -0.234227
# 2   5.903256 -0.907374  1.543015  1.932010 -5.333953  ...   0.386860
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0   0.627051   4.062862  -2.202540   8.769659  -0.688756   2.131949
# 1  -1.474790   0.882920  -5.764565   6.216725   0.120004  -0.121555
# 2   2.012475   0.839936  -7.306036  12.301046  -0.803223   2.854921
#
#    signal_58  signal_59  signal_60
# 0   0.034065  -5.066727  10.990295
# 1   0.248531  -3.796109   7.935419
# 2   1.994898  -8.802305  11.930964
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=28\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=31\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=35\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=38\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=41\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=45\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=48\ss=21\part-00000.parquet | size=92.8 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=51\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=55\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=00\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 00:58:21:000000  0.832543  0.158791  4.423454 -3.233279
# 1  08:21:2025 00:58:22:000000 -0.244165  0.475221  4.789758 -3.028007
# 2  08:21:2025 00:58:23:000000  0.368331 -0.515485  2.173310 -3.852851
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0   6.502594 -0.225802 -0.290566  3.214141 -3.988132  ...  -0.327292
# 1  12.316280  0.912411  0.893059  2.430984 -4.188550  ...   0.736693
# 2   5.143247 -0.355201 -1.198276  3.193917 -7.991162  ...   0.481423
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0  -2.138883   4.402196  -6.533537   9.204581  -0.737291  -2.166436
# 1  -2.222825   2.637893  -6.234592   6.313269  -0.211165  -2.499370
# 2   0.559204   1.539512  -4.542119   8.428803   0.202780  -2.243318
#
#    signal_58  signal_59  signal_60
# 0   1.261595  -7.699962  13.603492
# 1   2.027970  -8.352161  12.130198
# 2   1.096907  -6.569662  14.818478
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=21\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=25\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=28\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=31\ss=41\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 01:31:41:000000  0.643478 -0.301410  1.800556 -7.268674
# 1  08:21:2025 01:31:42:000000 -0.147248 -2.527699  0.952151 -9.109784
# 2  08:21:2025 01:31:43:000000  0.671383  1.650062  1.812544 -8.816982
#
#    signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0  9.781081  0.001445 -2.413628  3.040846 -4.231756  ...   0.728347
# 1  8.312917  0.140136 -1.264673  2.312476 -6.969845  ...  -0.769797
# 2  9.754338  0.288599 -2.102360  3.262378 -5.849400  ...   0.101432
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0   2.729067   2.285664  -3.991461   8.062318  -0.630869   0.314192
# 1   0.412185   1.630436  -8.762616   7.293314  -0.666959   1.811620
# 2   2.889133   2.618058  -8.299860   7.840339   0.123451   0.531348
#
#    signal_58  signal_59  signal_60
# 0   0.091829  -8.602317   9.241236
# 1   2.803930  -4.473453   9.260906
# 2   0.795486  -9.128570  11.042980
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=35\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=38\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=41\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=45\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=48\ss=21\part-00000.parquet | size=92.8 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=51\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=55\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=01\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 02:05:01:000000  0.617085 -2.944550  4.982461 -3.249463
# 1  08:21:2025 02:05:02:000000 -0.104703  1.788523  0.034117 -2.499566
# 2  08:21:2025 02:05:03:000000  0.381999  0.540616  0.496516 -5.919045
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0  14.446447  0.905805  1.367703  0.305450 -6.464036  ...  -0.760197
# 1  14.445781 -0.130884  2.150965  1.084541 -5.244094  ...   0.177600
# 2   9.858225  0.798175  1.333252  2.685601 -2.959272  ...   0.361124
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0  -2.980472   4.815582  -5.966918  10.841729  -0.531721  -0.615547
# 1   1.308660   4.611695  -9.808116  13.402764  -0.888028   0.871938
# 2   0.683863   3.038493  -9.410290   6.614257   0.498372   2.089569
#
#    signal_58  signal_59  signal_60
# 0   3.192293  -2.721733   7.295314
# 1   3.557867  -9.554747   9.475484
# 2   3.122528  -5.314448   5.655711
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=21\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=25\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=28\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=31\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=35\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=38\ss=21\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 02:38:21:000000 -0.658741  1.219882  0.907957 -9.563185
# 1  08:21:2025 02:38:22:000000  0.432552  0.132668  4.348126 -4.727551
# 2  08:21:2025 02:38:23:000000 -0.656507 -2.787830  0.787871 -3.840487
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0   9.956863  0.048767  2.812542  3.856912 -7.916601  ...  -0.626719
# 1  13.107201 -0.374436  2.187929  0.336444 -3.314282  ...   0.543122
# 2   7.098290 -0.024208 -1.043558  0.511736 -9.957860  ...  -0.681578
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0   0.161156   2.995402  -8.944154  11.704205  -0.774713  -0.325877
# 1   1.667618   2.932772  -6.889697   9.365781   0.158053   1.303194
# 2  -0.809909   4.229051  -9.978753  12.268796   0.813423  -0.891574
#
#    signal_58  signal_59  signal_60
# 0   2.127466  -6.391659   6.439521
# 1   2.172091  -5.647092   6.423034
# 2   1.243479  -5.632953  14.624096
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=41\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=45\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=48\ss=21\part-00000.parquet | size=92.8 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=51\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=55\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=02\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 03:11:41:000000 -0.375692  0.534541  0.695702 -8.253234
# 1  08:21:2025 03:11:42:000000 -0.887101 -2.627835  2.838686 -6.583253
# 2  08:21:2025 03:11:43:000000  0.394018 -0.548901  0.494080 -6.863556
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0  12.378226 -0.857928 -1.494721  3.903726 -2.351196  ...  -0.163970
# 1  13.909500 -0.581725  2.455364  3.358776 -2.000060  ...   0.081279
# 2   5.954041 -0.397531 -1.211852  2.335124 -2.663084  ...  -0.513732
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0  -1.844609   1.264254  -7.031682   5.397882   0.012791  -1.348371
# 1   2.764276   4.230713  -2.485828   9.988295   0.288752  -2.666829
# 2  -1.189357   3.355794  -5.264900  10.397439   0.392065  -2.182499
#
#    signal_58  signal_59  signal_60
# 0   3.662942  -5.175385   7.854237
# 1   0.997184  -4.839797   5.847415
# 2   3.161604  -6.850136   7.048793
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=21\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=25\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=28\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=31\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=35\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=38\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=41\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=45\ss=01\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 03:45:01:000000 -0.202690 -2.296878  1.849018 -8.496300
# 1  08:21:2025 03:45:02:000000 -0.389709 -1.074733  2.975175 -5.173495
# 2  08:21:2025 03:45:03:000000 -0.843257 -2.560932  4.313732 -6.987779
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0  11.464591  0.055370 -1.462920  1.539881 -3.905226  ...   0.202285
# 1   9.075788 -0.390045 -1.323199  3.982455 -5.505541  ...  -0.451248
# 2  12.710548 -0.788261  1.066938  1.796508 -2.501124  ...   0.696768
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0  -2.351972   2.285264  -9.608553  13.801854  -0.200143  -0.422389
# 1  -2.705282   2.132860  -7.641067  14.755235   0.030273  -2.176647
# 2  -0.274564   1.362242  -4.711797  14.478863   0.006624   0.424689
#
#    signal_58  signal_59  signal_60
# 0   1.625610  -8.384630  13.769977
# 1   1.141645  -2.911505   5.748080
# 2   4.018322  -5.518776  12.178500
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=48\ss=21\part-00000.parquet | size=92.8 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=51\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=55\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=03\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 04:18:21:000000  0.889723 -1.936160  2.446593 -9.459967
# 1  08:21:2025 04:18:22:000000 -0.763241  1.340365  0.487494 -7.366605
# 2  08:21:2025 04:18:23:000000  0.638220 -1.938876  2.096780 -6.987874
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0  10.891249 -0.228096  2.229659  2.211126 -9.726573  ...   0.215748
# 1  13.854414  0.822874 -0.744931  1.636943 -5.705374  ...  -0.348678
# 2   7.469219 -0.986363 -2.853891  2.622313 -9.497318  ...  -0.913406
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0  -0.807914   1.020361  -2.540647  11.885823   0.551957   0.376278
# 1  -0.674328   0.495619  -6.663149  11.768156   0.145828  -2.747957
# 2  -2.802717   2.029775  -2.775049   7.054224   0.284318  -1.884895
#
#    signal_58  signal_59  signal_60
# 0   4.403937  -3.087852  11.786590
# 1   0.115141  -6.076609  13.233475
# 2   3.469151  -5.807140  12.450076
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=21\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=25\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=28\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=31\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=35\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=38\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=41\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=45\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=48\ss=21\part-00000.parquet | size=92.8 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=51\ss=41\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 04:51:41:000000 -0.389663 -2.626197  3.697379 -5.110471
# 1  08:21:2025 04:51:42:000000 -0.909155 -0.512762  2.094706 -2.719011
# 2  08:21:2025 04:51:43:000000  0.569218  2.741489  0.036900 -2.904277
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0  13.393620 -0.713711 -2.618028  4.314184 -9.531470  ...   0.952893
# 1  11.334932 -0.770491  0.906431  3.818109 -8.693323  ...   0.783934
# 2  14.043469  0.867682  0.133909  1.151216 -2.650724  ...   0.041228
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0  -2.154905   2.383931  -3.484872   9.324931  -0.931675  -0.409401
# 1   2.045842   0.623101  -5.789531  11.932694   0.362434   0.179269
# 2   1.395705   1.450288  -6.030560  12.854002  -0.031315   2.982403
#
#    signal_58  signal_59  signal_60
# 0   1.553400  -4.441275   7.472273
# 1   4.840733  -2.497406   7.948774
# 2   4.069333  -9.717477   6.089589
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=55\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=04\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=21\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=25\ss=01\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 05:25:01:000000  0.711292 -0.660963  3.349805 -5.227004
# 1  08:21:2025 05:25:02:000000 -0.304110 -1.371092  0.203869 -7.314851
# 2  08:21:2025 05:25:03:000000  0.053211 -1.142696  4.116888 -3.508724
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0   5.585915 -0.576113 -2.186445  4.623026 -3.794028  ...  -0.107310
# 1  14.108425 -0.573195  1.541880  2.777018 -3.637608  ...   0.484446
# 2  12.360678 -0.661769  2.091901  2.709593 -6.771897  ...   0.663928
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0   2.928412   4.429181  -4.485756   8.849959  -0.359275   1.199936
# 1  -2.056947   3.182755  -5.119581   9.511600  -0.329526  -2.165603
# 2   2.495846   4.842532  -2.809824  11.557839  -0.268036   2.147567
#
#    signal_58  signal_59  signal_60
# 0   0.890981  -2.433858   8.692453
# 1   0.928853  -9.514565   8.339728
# 2   0.334788  -6.393182  13.552402
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=28\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=31\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=35\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=38\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=41\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=45\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=48\ss=21\part-00000.parquet | size=92.8 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=51\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=55\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=05\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 05:58:21:000000 -0.106385  1.567578  1.984458 -9.418932
# 1  08:21:2025 05:58:22:000000  0.811762 -0.333361  2.106154 -2.473775
# 2  08:21:2025 05:58:23:000000 -0.835296 -1.412652  4.537647 -8.768672
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0   9.190964 -0.094824  1.003532  0.659687 -3.719177  ...   0.458016
# 1   7.563361  0.828494  2.316568  2.056972 -8.630470  ...  -0.389092
# 2  10.559813  0.411070  2.142583  1.929460 -8.325017  ...   0.816183
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0   1.228512   1.132347  -4.623937  13.833412   0.929179   0.090355
# 1   0.934780   4.556022  -8.495803   7.057887   0.733685  -2.259998
# 2   0.960494   4.374314  -4.000998  12.027077   0.719599   0.947672
#
#    signal_58  signal_59  signal_60
# 0   4.139038  -4.195004   5.023227
# 1   2.373088  -4.927933   9.035244
# 2   2.286165  -4.881134  12.321691
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=21\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=25\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=28\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=31\ss=41\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 06:31:41:000000  0.042998 -0.981116  2.774759 -5.387207
# 1  08:21:2025 06:31:42:000000  0.175029  1.707431  2.819038 -6.478513
# 2  08:21:2025 06:31:43:000000 -0.746714  2.811980  0.166749 -2.269520
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0   6.268019  0.345336  0.819976  2.032239 -6.498108  ...   0.926002
# 1  11.280702 -0.838740 -2.984225  0.326252 -2.551513  ...  -0.123031
# 2   7.878928  0.645180  2.875996  4.167060 -6.536813  ...  -0.393680
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0   1.820076   0.942097  -5.336030   6.202541   0.992239   2.014357
# 1  -1.485444   1.875661  -4.243323  13.431732  -0.187086  -0.055867
# 2   0.161935   2.761815  -6.977727  12.336893   0.588058  -2.169638
#
#    signal_58  signal_59  signal_60
# 0   1.481780  -4.199088  14.495329
# 1   3.376039  -2.333739   6.751251
# 2   1.800159  -5.523767  12.491909
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=35\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=38\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=41\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=45\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=48\ss=21\part-00000.parquet | size=92.8 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=51\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=55\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=06\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 07:05:01:000000 -0.668727  1.749364  3.200302 -5.882944
# 1  08:21:2025 07:05:02:000000 -0.547934 -2.420374  2.857735 -3.925089
# 2  08:21:2025 07:05:03:000000  0.629943 -1.386916  3.515095 -4.596137
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0  11.625585 -0.930696 -0.776637  3.547521 -9.623931  ...   0.622183
# 1   7.807514  0.662722 -0.623718  4.890481 -6.309960  ...  -0.937860
# 2   8.209335  0.204387 -2.880246  3.605913 -2.937328  ...   0.219832
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0  -1.620363   1.075088  -9.293877   5.408067   0.822844   0.213383
# 1   0.747987   1.637607  -5.622859  11.911247   0.128493  -1.381327
# 2  -2.664371   2.514438  -8.332033  11.595588   0.469477   0.160439
#
#    signal_58  signal_59  signal_60
# 0   3.615541  -5.459122   7.236951
# 1   2.713764  -8.418733  11.557774
# 2   4.464298  -2.462786   5.291004
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=21\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=25\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=28\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=31\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=35\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=38\ss=21\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 07:38:21:000000  0.734491 -1.754983  2.838685 -9.621469
# 1  08:21:2025 07:38:22:000000  0.682365  2.688694  4.543704 -4.801025
# 2  08:21:2025 07:38:23:000000  0.393390 -1.736460  3.996463 -4.708056
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0   9.667259  0.682991 -0.006527  0.669506 -2.981474  ...  -0.975048
# 1  11.291162 -0.368790 -0.224732  4.125998 -4.490914  ...  -0.208096
# 2  11.823468 -0.703942 -1.002722  0.947047 -2.573388  ...   0.396195
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0   2.498885   0.760115  -8.182503   7.625590  -0.101897   1.519201
# 1   0.711770   3.724133  -4.717991   7.969899  -0.398599   2.614090
# 2   1.485085   1.255168  -5.523933  13.679863   0.521448   0.505602
#
#    signal_58  signal_59  signal_60
# 0   2.817044  -9.412052  10.827097
# 1   3.515639  -5.745586   5.765645
# 2   4.250389  -9.284444  14.401708
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=41\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=45\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=48\ss=21\part-00000.parquet | size=92.8 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=51\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=55\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=07\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 08:11:41:000000  0.235546  1.910094  2.798189 -2.570287
# 1  08:21:2025 08:11:42:000000  0.368272  1.013845  1.524840 -7.763052
# 2  08:21:2025 08:11:43:000000 -0.792385  1.090141  1.639306 -4.310492
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0   8.298123 -0.263779  1.988296  3.733683 -9.624104  ...  -0.313708
# 1  10.135000  0.735013 -1.028653  4.824359 -6.930547  ...   0.059469
# 2  12.961956  0.447655 -2.064741  3.016654 -4.908642  ...   0.844273
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0   0.752911   2.041978  -2.079996  12.964186  -0.691030   0.982510
# 1   0.698961   3.384483  -3.744632  12.499529  -0.513815  -1.281744
# 2   2.857150   4.632951  -9.804666   7.909753   0.116386   1.423114
#
#    signal_58  signal_59  signal_60
# 0   3.106964  -6.055123  10.688090
# 1   3.767258  -7.966407   6.761325
# 2   2.504825  -5.717773   6.290686
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=21\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=25\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=28\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=31\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=35\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=38\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=41\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=45\ss=01\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 08:45:01:000000 -0.757804 -2.149055  0.811648 -6.521371
# 1  08:21:2025 08:45:02:000000 -0.652834 -0.580950  3.639521 -6.607769
# 2  08:21:2025 08:45:03:000000 -0.091475 -1.909622  4.956832 -7.953062
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0   6.983590 -0.478194  0.452523  4.042925 -4.197028  ...  -0.712996
# 1  12.278555  0.162707  1.868114  4.458293 -4.691999  ...   0.001547
# 2   6.247556  0.699654 -2.676863  0.646928 -8.124043  ...   0.324872
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0   0.128797   0.772150  -5.642611   8.497674   0.342321   2.379708
# 1   0.931663   2.603574  -9.810567   6.371363   0.291881  -0.988136
# 2   1.373715   3.527444  -6.976094   8.067739   0.727751  -1.254231
#
#    signal_58  signal_59  signal_60
# 0   3.722444  -7.701088   9.260278
# 1   2.897658  -7.038030   8.363893
# 2   1.450495  -3.892972  11.578907
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=48\ss=21\part-00000.parquet | size=92.8 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=51\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=55\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=08\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=09\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=09\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=09\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=09\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=09\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=09\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 09:18:21:000000  0.352010  1.593334  4.099719 -4.090546
# 1  08:21:2025 09:18:22:000000  0.432018  1.815296  4.786276 -3.626414
# 2  08:21:2025 09:18:23:000000 -0.289286  1.933657  4.328402 -4.286186
#
# ...
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=09\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=21\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=25\ss=01\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 10:25:01:000000  0.980595  0.987176  0.090515 -2.701555
# 1  08:21:2025 10:25:02:000000 -0.738054  0.189475  3.924256 -3.787553
# 2  08:21:2025 10:25:03:000000  0.059720  2.774387  4.415679 -3.525907
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0   6.632623  0.599582  2.992107  3.598304 -7.411044  ...   0.879430
# 1  11.797493  0.081755  0.185970  4.493269 -5.313344  ...  -0.875148
# 2   6.986385 -0.180709 -1.489057  1.193555 -4.660459  ...   0.578541
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0  -1.365442   4.021513  -2.279138  13.829381  -0.252124  -2.381126
# 1  -0.456109   1.227014  -3.634240   6.282059   0.077943   2.865307
# 2  -2.971436   3.169757  -9.802855  12.521979  -0.161397   0.658621
#
#    signal_58  signal_59  signal_60
# 0   1.931079  -9.061586   5.733393
# 1   1.098126  -9.847187   6.799751
# 2   3.221511  -6.492380  14.908932
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=28\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=31\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=35\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=38\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=41\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=45\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=48\ss=21\part-00000.parquet | size=92.8 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=51\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=55\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=10\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 10:58:21:000000 -0.110912 -0.135303  0.595931 -4.404130
# 1  08:21:2025 10:58:22:000000 -0.793898 -1.005763  4.746662 -2.249226
# 2  08:21:2025 10:58:23:000000  0.310683  1.023876  3.593977 -3.431870
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0  11.004596  0.928727 -0.412956  0.888996 -2.881186  ...  -0.091513
# 1  14.405767  0.606141  0.534240  4.843169 -7.776875  ...   0.582370
# 2  12.431908  0.812608  1.506376  2.443621 -5.768019  ...  -0.399234
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0  -0.869936   0.826676  -6.893922  10.150135   0.835914   2.125853
# 1   1.558507   0.563725  -3.757969  11.182619  -0.151954  -2.978407
# 2  -2.864169   0.199770  -5.502781   7.548347   0.323414  -0.014208
#
#    signal_58  signal_59  signal_60
# 0   1.428348  -6.974284  13.792192
# 1   3.613442  -3.911552   5.290229
# 2   1.549013  -5.952761  11.345372
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=21\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=25\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=28\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=31\ss=41\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 11:31:41:000000  0.626727 -1.588573  0.309098 -7.860986
# 1  08:21:2025 11:31:42:000000 -0.956336  2.626897  3.635918 -5.392101
# 2  08:21:2025 11:31:43:000000  0.257689  2.738053  1.877944 -2.077779
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0  14.781851 -0.563133  2.380500  2.124518 -2.659128  ...   0.434767
# 1   9.770436 -0.297621 -1.577698  3.375497 -7.661539  ...   0.371754
# 2   6.340116 -0.673799  0.597135  0.577476 -8.124417  ...   0.656158
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0   0.869927   4.262205  -9.809587  10.994466  -0.413438   1.262879
# 1   0.825174   3.863195  -6.844843   8.056326   0.248658   0.894499
# 2   0.700169   1.493959  -4.053585   9.285463  -0.426721  -1.497071
#
#    signal_58  signal_59  signal_60
# 0   4.322697  -7.709825  14.981667
# 1   2.220243  -6.412183  13.648380
# 2   3.330998  -7.495569   6.546374
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=35\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=38\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=41\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=45\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=48\ss=21\part-00000.parquet | size=92.8 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=51\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=55\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=11\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 12:05:01:000000  0.925543 -1.681453  0.940292 -8.214471
# 1  08:21:2025 12:05:02:000000 -0.186673  2.915570  2.147524 -3.892184
# 2  08:21:2025 12:05:03:000000 -0.315720 -0.790330  4.926294 -8.570515
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0  12.493262 -0.356731 -1.851004  1.885233 -3.849744  ...   0.618475
# 1  14.475239 -0.002128  1.530309  0.872055 -7.700327  ...  -0.167076
# 2   8.780845  0.527393 -0.877111  2.246074 -8.889233  ...  -0.475366
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0   2.788284   3.451455  -3.588458  13.276137  -0.031791   0.980358
# 1  -0.552539   0.611265  -2.072816   7.305133   0.161363  -0.638513
# 2  -0.957798   3.702329  -5.328362   9.428995   0.220890   2.382704
#
#    signal_58  signal_59  signal_60
# 0   2.875088  -2.815741  10.472327
# 1   4.584130  -9.705948  11.492810
# 2   3.339458  -4.992686   8.082782
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=21\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=25\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=28\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=31\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=35\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=38\ss=21\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 12:38:21:000000  0.278522  2.500937  1.569584 -4.594523
# 1  08:21:2025 12:38:22:000000  0.795949 -1.842197  0.638509 -2.677951
# 2  08:21:2025 12:38:23:000000  0.130806  2.500411  4.594381 -2.926294
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0   5.434677  0.107032  1.240691  0.265828 -4.420176  ...  -0.137592
# 1  12.766975 -0.193450 -2.477258  2.216230 -3.868003  ...  -0.441323
# 2   8.094084 -0.872437 -1.497835  3.802997 -3.351483  ...   0.293433
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0  -1.981923   0.320706  -9.989316  11.179244  -0.275199   1.151483
# 1   2.753953   2.726119  -6.673863   7.650175  -0.070261  -2.528538
# 2  -0.208293   4.362083  -8.087507  14.296167  -0.527159   0.355432
#
#    signal_58  signal_59  signal_60
# 0   4.528581  -7.529284   5.617353
# 1   3.078365  -6.884255  10.553309
# 2   1.269020  -6.725460   5.251040
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=41\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=45\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=48\ss=21\part-00000.parquet | size=92.8 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=51\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=55\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=12\mm=58\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=13\mm=01\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=13\mm=05\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=13\mm=08\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=13\mm=11\ss=41\part-00000.parquet | size=92.9 KB
# [monitor]   sample 3 rows from part-00000.parquet:
#                     Timestamp  signal_1  signal_2  signal_3  signal_4  \
# 0  08:21:2025 13:11:41:000000 -0.792161 -0.630679  4.674247 -5.452499
# 1  08:21:2025 13:11:42:000000  0.301685 -0.821391  1.599233 -4.410331
# 2  08:21:2025 13:11:43:000000 -0.488906  2.222598  0.360951 -3.021876
#
#     signal_5  signal_6  signal_7  signal_8  signal_9  ...  signal_51  \
# 0   5.581733 -0.591900 -2.593812  2.782287 -2.702739  ...   0.885454
# 1   6.952593 -0.469745  2.890785  1.132353 -8.967004  ...  -0.067374
# 2  13.839300 -0.083599 -1.153895  1.929675 -5.366908  ...   0.167036
#
#    signal_52  signal_53  signal_54  signal_55  signal_56  signal_57  \
# 0  -0.954135   3.201400  -3.175742  11.537915   0.484768   0.550755
# 1   2.403810   3.357298  -3.747001   5.303615   0.634257  -0.283346
# 2   2.668253   2.890196  -9.951056  14.459025   0.733445   0.891452
#
#    signal_58  signal_59  signal_60
# 0   1.358537  -4.967762  10.260974
# 1   0.363075  -3.061567  11.154191
# 2   1.847717  -6.199192   5.407349
#
# [3 rows x 61 columns]
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=13\mm=15\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=13\mm=18\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=13\mm=21\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=13\mm=25\ss=01\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=13\mm=28\ss=21\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=13\mm=31\ss=41\part-00000.parquet | size=92.9 KB
# [monitor] + new file: C:\Users\Ishaan Tiwari\Desktop\Kafka\landing\YYYY=2025\MM=08\DD=21\HH=13\mm=35\ss=01\part-00000.parquet | size=92.9 KB
# Stopped real-time producer.

# %% [markdown]
# ## Write Monitor

# %%
# %% 
# Live monitor for landing/ that prints new Parquet files as they appear.
# No extra packages needed; simple polling + a background thread.

import threading, time, os
from pathlib import Path
from typing import Set

_MONITOR_THREAD = None
_MONITOR_STOP = threading.Event()

def _bytes_to_human(n: int) -> str:
    for unit in ['B','KB','MB','GB','TB']:
        if n < 1024.0:
            return f"{n:,.1f} {unit}"
        n /= 1024.0
    return f"{n:.1f} PB"

def _list_parquet_files(base: Path) -> Set[Path]:
    return set(base.rglob("*.parquet"))

def _monitor_loop(base: Path, sample_every: int = 10, read_sample_rows: int = 3):
    seen = _list_parquet_files(base)
    count = len(seen)
    print(f"[monitor] watching {base.resolve()} | existing parquet files: {count}")
    last_sampled = 0
    while not _MONITOR_STOP.is_set():
        time.sleep(1.0)  # poll every second
        current = _list_parquet_files(base)
        new = current - seen
        if new:
            # Sort by mtime for nicer ordering
            new_sorted = sorted(new, key=lambda p: p.stat().st_mtime)
            for p in new_sorted:
                size = _bytes_to_human(p.stat().st_size)
                print(f"[monitor] + new file: {p} | size={size}")
                count += 1
                # Occasionally peek inside to verify schema & a few rows
                if read_sample_rows > 0 and (count - last_sampled) >= sample_every:
                    try:
                        import pandas as pd
                        df = pd.read_parquet(p)
                        print(f"[monitor]   sample {read_sample_rows} rows from {p.name}:")
                        print(df.head(read_sample_rows))
                        last_sampled = count
                    except Exception as e:
                        print(f"[monitor]   (could not read sample) {e}")
        seen = current

def start_landing_monitor(base_dir: Path = LANDING_DIR, sample_every: int = 10, read_sample_rows: int = 3):
    """Start background monitor thread. Call once."""
    global _MONITOR_THREAD, _MONITOR_STOP
    if _MONITOR_THREAD is not None and _MONITOR_THREAD.is_alive():
        print("[monitor] already running")
        return
    _MONITOR_STOP.clear()
    _MONITOR_THREAD = threading.Thread(
        target=_monitor_loop, 
        args=(base_dir, sample_every, read_sample_rows),
        daemon=True
    )
    _MONITOR_THREAD.start()
    print("[monitor] started")

def stop_landing_monitor():
    """Stop background monitor thread."""
    global _MONITOR_THREAD, _MONITOR_STOP
    if _MONITOR_THREAD is None:
        print("[monitor] not running")
        return
    _MONITOR_STOP.set()
    _MONITOR_THREAD.join(timeout=5)
    _MONITOR_THREAD = None
    print("[monitor] stopped")

# %% [markdown]
# ### Start Monitor : Run monitor before running writer

# %%
# %%
start_landing_monitor(base_dir=LANDING_DIR, sample_every=10, read_sample_rows=3)
# Out:
# [monitor] started
# [monitor] watching C:\Users\Ishaan Tiwari\Desktop\Kafka\landing | existing parquet files: 195

# %% [markdown]
# ### Stop Monitor

# %%
# %%
stop_landing_monitor()
# Out:
# [monitor] stopped

# %% [markdown]
# ## Clear Lander Folder : Run Only when Writer in not running.

# %%
# %% 
# A0) HARD RESET: remove ALL previous landing data
from pathlib import Path
import shutil

LANDING_DIR = Path(r"C:\Users\Ishaan Tiwari\Desktop\Kafka\landing")


def reset_landing(base: Path = LANDING_DIR):
    if base.exists():
        shutil.rmtree(base)
    base.mkdir(parents=True, exist_ok=True)
    print(f"[reset] Cleaned and recreated {base.resolve()}")

# Stop the writer loop first, then run:
reset_landing()
# Out:
# [reset] Cleaned and recreated C:\Users\Ishaan Tiwari\Desktop\Kafka\landing
